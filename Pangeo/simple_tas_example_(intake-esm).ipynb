# %% [markdown]
# ### Pangeo: Simple One Dataset Example Using Intake-Esm
#
# Pangeo also offers the CMIP6 data in so called intake-esm catalogs. This example shows how to search for data from Pangeo using `intake-esm` and how to visualize a dataset with basic maps.
#
#
# **Packages:**
#
# - matplotlib
# - cftime
# - pandas
#     - *tool for reading data*, *data analysis and manipulation*
# - xarray
#     - *for handling of multidimensional arrays*
# - intake
#     - *for finding, investigating and loading data*
# - intake-esm
#     - *for connecting to database and loading data into xarray.Datasets, (built on top of pandas, xarray and intake)*
# - cartopy
#     - *for processing geospatial data and creating maps*

# %%
import matplotlib.pyplot as plt
import xarray as xr 
import intake

# %%
#url for connecting to Pangeo
url = "https://raw.githubusercontent.com/NCAR/intake-esm-datastore/master/catalogs/pangeo-cmip6.json"

#opening data catalog using intake_esm
dataframe = intake.open_esm_datastore(url)

# %%
#searching for datasets (historical monthly surface air temperature from NCAR)
models = dataframe.search(institution_id='NCAR', experiment_id='historical', table_id='Amon', variable_id='tas')
models
# Out:
# <p><strong>pangeo-cmip6 catalog with 4 dataset(s) from 20 asset(s)</strong>:</p> <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>unique</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>activity_id</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>institution_id</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>source_id</th>
#       <td>4</td>
#     </tr>
#     <tr>
#       <th>experiment_id</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>member_id</th>
#       <td>11</td>
#     </tr>
#     <tr>
#       <th>table_id</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>variable_id</th>
#       <td>1</td>
# ...

# %%
#getting better idea of the datasets
models.df
# Out:
#    activity_id institution_id        source_id experiment_id  member_id  \
# 0         CMIP           NCAR      CESM2-WACCM    historical   r2i1p1f1
# 1         CMIP           NCAR      CESM2-WACCM    historical   r3i1p1f1
# 2         CMIP           NCAR      CESM2-WACCM    historical   r1i1p1f1
# 3         CMIP           NCAR            CESM2    historical   r1i1p1f1
# 4         CMIP           NCAR            CESM2    historical   r4i1p1f1
# 5         CMIP           NCAR            CESM2    historical   r5i1p1f1
# 6         CMIP           NCAR            CESM2    historical   r2i1p1f1
# 7         CMIP           NCAR            CESM2    historical   r3i1p1f1
# 8         CMIP           NCAR            CESM2    historical   r6i1p1f1
# 9         CMIP           NCAR            CESM2    historical   r8i1p1f1
# 10        CMIP           NCAR            CESM2    historical   r7i1p1f1
# 11        CMIP           NCAR            CESM2    historical   r9i1p1f1
# ...

# %%
#loading datasets into dictionary
datasets = models.to_dataset_dict()
#next we want to see the keys to each dataset
for key in datasets.keys():
    print(key)
# Out:
# --> The keys in the returned dictionary of datasets are constructed as follows:
# 	'activity_id.institution_id.source_id.experiment_id.table_id.grid_label'
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
#       <progress value='4' class='' max='4' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [4/4 00:05&lt;00:00]
#     </div>
# CMIP.NCAR.CESM2-WACCM.historical.Amon.gn
# ...

# %%
#you can simply copy the key from the above and access dataset like this
ds = datasets['CMIP.NCAR.CESM2.historical.Amon.gn']
#checking the metadata will give you better idea of what the dataset actually contains
ds
# Out:
# <xarray.Dataset>
# Dimensions:    (lat: 192, nbnd: 2, lon: 288, member_id: 11, time: 1980)
# Coordinates:
#   * lat        (lat) float64 -90.0 -89.06 -88.12 -87.17 ... 88.12 89.06 90.0
#     lat_bnds   (lat, nbnd) float32 dask.array<chunksize=(192, 2), meta=np.ndarray>
#   * lon        (lon) float64 0.0 1.25 2.5 3.75 5.0 ... 355.0 356.2 357.5 358.8
#     lon_bnds   (lon, nbnd) float32 dask.array<chunksize=(288, 2), meta=np.ndarray>
#   * time       (time) object 1850-01-15 12:00:00 ... 2014-12-15 12:00:00
#     time_bnds  (time, nbnd) object dask.array<chunksize=(1980, 2), meta=np.ndarray>
#   * member_id  (member_id) <U9 'r1i1p1f1' 'r4i1p1f1' ... 'r10i1p1f1' 'r11i1p1f1'
# Dimensions without coordinates: nbnd
# Data variables:
#     tas        (member_id, time, lat, lon) float32 dask.array<chunksize=(1, 600, 192, 288), meta=np.ndarray>
# Attributes: (12/50)
#     case_id:                 972
#     forcing_index:           1
#     frequency:               mon
# ...

# %%
# selecting first member-id
var = ds[ds.variable_id].isel(member_id=0)
name = var.long_name
units = var.units
var
# Out:
# <xarray.DataArray 'tas' (time: 1980, lat: 192, lon: 288)>
# dask.array<getitem, shape=(1980, 192, 288), dtype=float32, chunksize=(600, 192, 288), chunktype=numpy.ndarray>
# Coordinates:
#   * lat        (lat) float64 -90.0 -89.06 -88.12 -87.17 ... 88.12 89.06 90.0
#   * lon        (lon) float64 0.0 1.25 2.5 3.75 5.0 ... 355.0 356.2 357.5 358.8
#   * time       (time) object 1850-01-15 12:00:00 ... 2014-12-15 12:00:00
#     member_id  <U9 'r1i1p1f1'
# Attributes:
#     cell_measures:  area: areacella
#     cell_methods:   area: time: mean
#     comment:        near-surface (usually, 2 meter) air temperature
#     description:    near-surface (usually, 2 meter) air temperature
#     frequency:      mon
#     id:             tas
#     long_name:      Near-Surface Air Temperature
#     mipTable:       Amon
#     out_name:       tas
#     prov:           Amon ((isd.003))
#     realm:          atmos
#     standard_name:  air_temperature
#     time:           time
# ...

# %%
#choose the time you want to plot
t = '1850-01'

# %%
#simple plot of the selected data
var.sel(time= t).squeeze().plot()

# %%
#this is the same figure formatted differently and with celsius degrees
if ds.variable_id == 'tas':
    var = var - 273.15
    units = '$ ^\circ $C'
var.sel(time= t).squeeze().plot(aspect=2, size=5, cmap=plt.cm.coolwarm, cbar_kwargs={"label": f"{name}\n [{units}]"})

# %%
#with cartopy there is even more ways to adjust maps
import cartopy.crs as ccrs
from cartopy.util import add_cyclic_point

#creating map with robinson style projection
fig = plt.figure(figsize=(11,8.5))
ax=plt.axes(projection=ccrs.Robinson())

#defining data and coordinates
data= var.sel(time= t)
data, lons = add_cyclic_point(data, coord=ds.lon)
lats = ds.lat

cs = plt.contourf(lons, lats, data.squeeze(), 11, transform = ccrs.PlateCarree(), cmap='coolwarm', extend='both')

#adding coastlines
ax.coastlines()

#adding horizontal colorbar and title
cbar = plt.colorbar(cs,shrink=0.7,orientation='horizontal', label=f'{units}')
plt.title(f'{name} {t}', size=15)
# Out:
# Text(0.5, 1.0, 'Near-Surface Air Temperature 1850-01')
